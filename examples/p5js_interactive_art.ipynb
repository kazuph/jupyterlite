// %% [markdown]
// # Interactive Art with p5.jsThis notebook uses the p5.js kernel to create a simple interactive drawing canvas.
//
// Move your mouse over the canvas below to draw!

// %%
function setup() {
  createCanvas(400, 400);
  background(20);
}

function draw() {
  // This function is called in a loop
}

function mouseDragged() {
  stroke(255, 200, 220);
  strokeWeight(4);
  line(mouseX, mouseY, pmouseX, pmouseY);
}

// %%
%show
